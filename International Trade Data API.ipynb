# %% [markdown]
# # International Trade Data - Census API

# %% [markdown]
# The purpose of this project is to download data from the Monthly International Trade Dataset (MITD) by using Census API.
#
# To make more than 500 API calls a day, Census API requires users to sign up for an API Key. To get one, register [here](http://api.census.gov/data/key_signup.html).

# %% [markdown]
# ## About the Data

# %% [markdown]
# In this project, we'll be downloading 2-digit Harmonized System (HS) data. HS is an international classification system administered by the World Customs Organization.

# %%
import numpy as np
import pandas as pd
import requests

# no decimal places
pd.options.display.float_format = '{:,.0f}'.format
# show more rows
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Commodities
#
# Commodities list consists of **97** unique 2-digit HS codes. An example would be 01, which stands for live animals.
# The list used as a reference point is obtained from the [U.S. Census Bureau](https://www.census.gov/foreign-trade/schedules/b/2020/index.html). The existing commodity descriptions in this list will be replaced with simplified and easier-to-read descriptions as defined in the Houston Global publication issued by the Greater Houston Partnership.

# %%
commodities = pd.read_csv('C:/Users/Berina/Desktop/Trade Data - API/hs2_commodities.csv', header=None, dtype=object)
comm_alter_names = pd.read_csv('C:/Users/Berina/Desktop/Trade Data - API/commodities_alter_names.csv', 
                               header=None, dtype=object)

# initially comm_alter_names has 99 rows and 4 columns
# delete the two columns with NaN values
comm_alter_names.drop(labels=[2,3], axis=1,inplace=True)
# extract the two-digit codes from the first column
comm_alter_names['COMMODITY_CODE'] = comm_alter_names.iloc[:,0].str[0:2]
# drop rows with null values - this brings the list down to 97 rows
comm_alter_names = comm_alter_names[comm_alter_names['COMMODITY_CODE'].notnull()]
# delete the first column and rename the second one
comm_alter_names.drop(labels=0, axis=1, inplace=True)
comm_alter_names.rename(columns={1: 'COMMODITY'}, inplace=True)

# update column names for the commodities dataframe
commodities.columns = ['COMMODITY_CODE', 'LONG_NAME']

# combine the two files as well as verify the alternative list has all the right matches
commodities = pd.merge(left=commodities, right=comm_alter_names, on='COMMODITY_CODE', how='left')
# commodities.info() --> all three columns have 97 non-null object entries

# drop the long name
commodities.drop(labels='LONG_NAME', axis=1, inplace=True)

# prepare a list of commodity codes needed for API calls
commodity_codes = commodities.loc[:,'COMMODITY_CODE'].tolist()

# %% [markdown]
# ### Districts
#
# District codes are 2-digit unique identifiers for a total of **44** U.S. districts. The codes range from 01 to 55. An example district code is 53, which stands for Houston-Galveston, TX. The list of districts is also sourced from the [U.S.Census Bureau](https://www.census.gov/foreign-trade/schedules/d/dist2.txt).

# %%
districts = pd.read_csv('C:/Users/Berina/Desktop/Trade Data - API/districts.csv', header=None, dtype=object)
# rename the columns
districts.columns = ['DISTRICT_CODE', 'DISTRICT']

# prepare a list of district codes needed for API calls
district_codes = districts.loc[:,'DISTRICT_CODE'].tolist()

# %% [markdown]
# ### Countries
#
# Country codes are 4-digit unique identifiers and some examples include 1000, 1010, 1220, etc. For example, 1220 stands for Canada. This list consists of **241** countries and it is updated to reflect current geopolitical factors. The original list can be found [here](https://www.census.gov/foreign-trade/schedules/c/country2.txt).
# Given that the countries list is longer than both commodities and districts lists, it will not be used for builing API queries. The reason it's necessary, however, is that we will be adding country names to the finalized dataset.

# %%
countries = pd.read_csv('C:/Users/Berina/Desktop/Trade Data - API/countries.csv', header=None, dtype=object)

# remove the last column, the country abbreviations, since it is not necessary
countries.drop(labels=2, axis=1, inplace=True)
# set column names
country_cols = ['COUNTRY_CODE', 'COUNTRY']
countries.columns = country_cols

# abbreviate long country names
#   Falkland Islands (Islas Malvinas)                          --> Falkland Islands
#   Denmark, except Greenland                                  --> Denmark
#   Germany (Federal Repulic of Germany)                       --> Germany
#   Moldova (Repulic of Moldova)                               --> Moldova
#   Holy See (Vatican City)                                    --> Vatican City
#   Syria (Syrian Arab Republic)                               --> Syria
#   Gaza Strip administered by Israel                          --> Gaza Strip
#   West Bank administered by Israel                           --> West Bank
#   Yemen (Republic of Yemen)                                  --> Yemen
#   Burma (Myanmar)                                            --> Myanmar
#   Laos (Lao People's Democratic Republic)                    --> Laos
#   North Korea (democratic People's Republic of Korea)        --> North Korea
#   South Korea (Republic of Korea)                            --> South Korea
#   Samoa (Western Samoa)                                      --> Samoa
#   Micronesia, Federated States of                            --> Micronesia
#   Congo, Republic of the Congo                               --> Congo-Brazzaville
#   Congo, Democratic Republic of the Congo (formerly Za[ire)] --> Congo-Kinshasa
#   Tanzania (United Republic of Tanzania)                     --> Tanzania
#   Christmas Island (in the Indian Ocean)                     --> Christmas Island

# make a dictionary with shorter country name alternatives
updated_country_names = {'Falkland Islands (Islas Malvinas)': 'Falkland Islands',
                         'Denmark, except Greenland': 'Denmark',
                         'Germany (Federal Republic of Germany)': 'Germany',
                         'Moldova (Republic of Moldova)': 'Moldova',
                         'Holy See (Vatican City)': 'Vatican City',
                         'Syria (Syrian Arab Republic)': 'Syria',
                         'Gaza Strip administered by Israel': 'Gaza Strip',
                         'West Bank administered by Israel': 'West Bank',
                         'Yemen (Republic of Yemen)': 'Yemen',
                         'Burma (Myanmar)': 'Myanmar',
                         'Laos (Lao People\'s Democratic Republic)': 'Laos',
                         'North Korea (Democratic People\'s Republic of Korea)': 'North Korea',
                         'South Korea (Republic of Korea)': 'South Korea',
                         'Samoa (Western Samoa)': 'Samoa',
                         'Micronesia, Federated States of': 'Micronesia',
                         'Congo, Republic of the Congo': 'Congo-Brazzaville',
                         'Congo, Democratic Republic of the Congo (formerly Za': 'Congo-Kinshasa',
                         'Tanzania (United Republic of Tanzania)': 'Tanzania',
                         'Christmas Island (in the Indian Ocean)': 'Christmas Island'}

# clean any unwanted whitespace
countries.loc[:,'COUNTRY_CODE'] = countries.loc[:,'COUNTRY_CODE'].str.strip()
countries.loc[:,'COUNTRY'] = countries.loc[:,'COUNTRY'].str.strip()
# replace the long names
countries.loc[:,'COUNTRY'].replace(to_replace=updated_country_names, inplace=True)

# %% [markdown]
# ### Monthly International Trade Data API Structure
#
# API for MITD data has two endpoints: exports and imports. There are several datasets available for each, but as mentioned previously, we will be using the HS data. This means that although both exports and imports have an HS dataset available, a separate API call will have to be made to access each.
#
# The general structure of the API call includes the UNIFORM RESOURCE IDENTIFIERS (URIs) of the MITD endpoints
#     ``https://api.census.gov/data/timeseries/intltrade/exports/hs?get=``, where hs stands for the HS dataset. This is an example for the exports endpoint. Getting imports is as simple as typing imports instead of exports.
#
# To complete the rest of the API call, we use parameters. There are more than 50 available parameters for both exports and imports. For this project, we will use the following:
#
#             CTY_CODE        --> country code
#             ALL_VAL_MO      --> total value, monthly
#             AIR_VAL_MO      --> air value, monthly
#             AIR_WGT_MO      --> air shipping weight, monthly
#             VES_VAL_MO      --> vessel value, monthly
#             VES_WGT_MO      --> vessel shipping weight, monthly
#             SUMMARY_LVL=DET --> selecting individual countries, not predefined groups
#             time            --> YYYY-MM format, or from+YYYY-MM+to+YYYY-MM if multiple months
#             E(I)_COMMODITY  --> export/import commodity code
#             DISTRICT        --> district code
#
# For more information on how to build MITD API queries, refer to the [International Trade Data - API User Guide](https://www.census.gov/foreign-trade/reference/guides/Guide%20to%20International%20Trade%20Datasets.pdf) published by the U.S. Census Bureau.

# %% [markdown]
# ### Getting the Data
# ***

# %%
# shorten the lists to test the code on a smaller sample size
# first five commodity codes
alter_comm_codes = commodity_codes[0:5]
# last five district codes
alter_dist_codes = district_codes[-5:]

# %%
key = 'c64e82bd341ac24cc8223afd0458afb0f3436c66' # insert your API key here

# it is advisable to split the time interval into smaller pieces as requesting too much data at once may cause performance 
# issues; in general, the API can handle a large number of smaller calls better than a few large data calls
time = ['from+2018-01+to+2018-12', 'from+2019-01+to+2019-12']

# Fixed URI parts 
exports_endpoint = "https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key="
imports_endpoint = "https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key="

# control variable used to identify the first successful API call
status_success = 0

for t in time:
    for commodity in alter_comm_codes:
        for district in alter_dist_codes:
            # build the custom API call
            exp_api = exports_endpoint + key + '&time=' + t + '&E_COMMODITY=' + commodity + '&DISTRICT=' + district
            imp_api = imports_endpoint + key + '&time=' + t + '&I_COMMODITY=' + commodity + '&DISTRICT=' + district
            # Requesting API
            for api in [exp_api, imp_api]:
                api_response = requests.get(api)
                print(api_response.status_code)
                print(api)
                # status code 200 means the server returned a result
                # 204 stands for a good request but no records for the given combination of parameters
                # everything else reads trouble
                if api_response.status_code == 200:
                    status_success += 1
                    # print('Commodity Code: ', commodity, '         District Code: ', district, '\n')
                    # save the first successful query result as a dataframe
                    if status_success == 1:
                        data = pd.DataFrame(api_response.json())
                        # denote the data type
                        data['type'] = 'Exports' if api == exp_api else 'Imports'
                    # concatenate subsequent successful query results
                    else:
                        data_2 = pd.DataFrame(api_response.json())
                        data_2['type'] = 'Exports' if api == exp_api else 'Imports'
                        data = pd.concat([data, data_2.iloc[1:,:]])
# Out:
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=01&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=01&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=01&DISTRICT=52
# Commodity Code:  01          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=01&DISTRICT=52
# Commodity Code:  01          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=01&DISTRICT=53
# Commodity Code:  01          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=01&DISTRICT=53
# Commodity Code:  01          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=01&DISTRICT=54
# Commodity Code:  01          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=01&DISTRICT=54
# Commodity Code:  01          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=01&DISTRICT=55
# Commodity Code:  01          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=01&DISTRICT=55
# Commodity Code:  01          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=02&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=02&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=02&DISTRICT=52
# Commodity Code:  02          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=02&DISTRICT=52
# Commodity Code:  02          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=02&DISTRICT=53
# Commodity Code:  02          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=02&DISTRICT=53
# Commodity Code:  02          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=02&DISTRICT=54
# Commodity Code:  02          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=02&DISTRICT=54
# Commodity Code:  02          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=02&DISTRICT=55
# Commodity Code:  02          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=02&DISTRICT=55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=03&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=03&DISTRICT=51
# Commodity Code:  03          District Code:  51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=03&DISTRICT=52
# Commodity Code:  03          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=03&DISTRICT=52
# Commodity Code:  03          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=03&DISTRICT=53
# Commodity Code:  03          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=03&DISTRICT=53
# Commodity Code:  03          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=03&DISTRICT=54
# Commodity Code:  03          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=03&DISTRICT=54
# Commodity Code:  03          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=03&DISTRICT=55
# Commodity Code:  03          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=03&DISTRICT=55
# Commodity Code:  03          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=04&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=04&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=04&DISTRICT=52
# Commodity Code:  04          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=04&DISTRICT=52
# Commodity Code:  04          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=04&DISTRICT=53
# Commodity Code:  04          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=04&DISTRICT=53
# Commodity Code:  04          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=04&DISTRICT=54
# Commodity Code:  04          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=04&DISTRICT=54
# Commodity Code:  04          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=04&DISTRICT=55
# Commodity Code:  04          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=04&DISTRICT=55
# Commodity Code:  04          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=05&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=05&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=05&DISTRICT=52
# Commodity Code:  05          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=05&DISTRICT=52
# Commodity Code:  05          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=05&DISTRICT=53
# Commodity Code:  05          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=05&DISTRICT=53
# Commodity Code:  05          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=05&DISTRICT=54
# Commodity Code:  05          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=05&DISTRICT=54
# Commodity Code:  05          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&E_COMMODITY=05&DISTRICT=55
# Commodity Code:  05          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2018-01+to+2018-12&I_COMMODITY=05&DISTRICT=55
# Commodity Code:  05          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=01&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=01&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=01&DISTRICT=52
# Commodity Code:  01          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=01&DISTRICT=52
# Commodity Code:  01          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=01&DISTRICT=53
# Commodity Code:  01          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=01&DISTRICT=53
# Commodity Code:  01          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=01&DISTRICT=54
# Commodity Code:  01          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=01&DISTRICT=54
# Commodity Code:  01          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=01&DISTRICT=55
# Commodity Code:  01          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=01&DISTRICT=55
# Commodity Code:  01          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=02&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=02&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=02&DISTRICT=52
# Commodity Code:  02          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=02&DISTRICT=52
# Commodity Code:  02          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=02&DISTRICT=53
# Commodity Code:  02          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=02&DISTRICT=53
# Commodity Code:  02          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=02&DISTRICT=54
# Commodity Code:  02          District Code:  54
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=02&DISTRICT=54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=02&DISTRICT=55
# Commodity Code:  02          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=02&DISTRICT=55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=03&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=03&DISTRICT=51
# Commodity Code:  03          District Code:  51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=03&DISTRICT=52
# Commodity Code:  03          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=03&DISTRICT=52
# Commodity Code:  03          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=03&DISTRICT=53
# Commodity Code:  03          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=03&DISTRICT=53
# Commodity Code:  03          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=03&DISTRICT=54
# Commodity Code:  03          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=03&DISTRICT=54
# Commodity Code:  03          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=03&DISTRICT=55
# Commodity Code:  03          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=03&DISTRICT=55
# Commodity Code:  03          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=04&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=04&DISTRICT=51
# Commodity Code:  04          District Code:  51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=04&DISTRICT=52
# Commodity Code:  04          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=04&DISTRICT=52
# Commodity Code:  04          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=04&DISTRICT=53
# Commodity Code:  04          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=04&DISTRICT=53
# Commodity Code:  04          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=04&DISTRICT=54
# Commodity Code:  04          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=04&DISTRICT=54
# Commodity Code:  04          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=04&DISTRICT=55
# Commodity Code:  04          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=04&DISTRICT=55
# Commodity Code:  04          District Code:  55
# 204
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=05&DISTRICT=51
# 204
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=05&DISTRICT=51
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=05&DISTRICT=52
# Commodity Code:  05          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=05&DISTRICT=52
# Commodity Code:  05          District Code:  52
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=05&DISTRICT=53
# Commodity Code:  05          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=05&DISTRICT=53
# Commodity Code:  05          District Code:  53
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=05&DISTRICT=54
# Commodity Code:  05          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=05&DISTRICT=54
# Commodity Code:  05          District Code:  54
# 200
# https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_CODE,ALL_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&E_COMMODITY=05&DISTRICT=55
# Commodity Code:  05          District Code:  55
# 200
# https://api.census.gov/data/timeseries/intltrade/imports/hs?get=CTY_CODE,GEN_VAL_MO,AIR_VAL_MO,AIR_WGT_MO,VES_VAL_MO,VES_WGT_MO&SUMMARY_LVL=DET&key=c64e82bd341ac24cc8223afd0458afb0f3436c66&time=from+2019-01+to+2019-12&I_COMMODITY=05&DISTRICT=55
# Commodity Code:  05          District Code:  55

# %% [markdown]
# ### Cleaning the Data
# ***
# To prepare the data for use, we need to do several steps including assigning meaningful column names, deleting unecessary columns and rows, adding year and month columns, adding country, commodity and district names and converting intrinsically numerical variables from strings to numerals.

# %%
data.head()
# Out:
#           0           1           2           3           4           5  \
# 0  CTY_CODE  ALL_VAL_MO  AIR_VAL_MO  AIR_WGT_MO  VES_VAL_MO  VES_WGT_MO
# 1         -     6317585     6302719      156064       14866        2981
# 2         -     4527629     4392416      187891      135213       31478
# 3         -     8953527     8632870      118855      320657      137754
# 4         -    14447059    14384371      290089       62688       23193
#
#              6        7            8         9     type
# 0  SUMMARY_LVL     time  E_COMMODITY  DISTRICT  Exports
# 1          DET  2018-01           01        52  Exports
# 2          DET  2018-02           01        52  Exports
# 3          DET  2018-03           01        52  Exports
# 4          DET  2018-04           01        52  Exports

# %%
# dictionary with preferred replacements for default column names obtained through API
column_names = {'CTY_CODE': 'COUNTRY_CODE',
                'ALL_VAL_MO': 'VALUE',
                'AIR_VAL_MO': 'AIR_VALUE',
                'AIR_WGT_MO': 'AIR_WEIGHT',
                'VES_VAL_MO': 'VESSEL_VALUE',
                'VES_WGT_MO': 'VESSEL_WEIGHT',
                'E_COMMODITY': 'COMMODITY_CODE',
                'I_COMMODITY': 'COMMODITY_CODE',
                'DISTRICT': 'DISTRICT_CODE',
                'Imports': 'TYPE',
                'Exports': 'TYPE'}

# replace the default column names (which are now in the first row) with the preferred ones
data.iloc[0,:].replace(to_replace=column_names, inplace=True)
# take the first row, convert to upper case, create a list and assign as a header
data.columns = data.iloc[0].str.upper().tolist()
# delete the first row
data.drop(labels=0, inplace=True)

# drop the SUMMARY_LVL column
data.drop(labels='SUMMARY_LVL', axis=1, inplace=True)
# to maintain consistency and ensure all the entries are monthly data, delete rows where CTY_CODE = '-'
data = data[data['COUNTRY_CODE'] != '-']

# separate the TIME column into columns YEAR and MONTH
data[['YEAR','MONTH']] = data['TIME'].str.split("-", expand=True)
# delete the TIME column
data.drop(labels='TIME', axis=1, inplace=True)

# add country, commodity and district names to the dataset
data = pd.merge(left=data, right=countries, on='COUNTRY_CODE', how='left')
data = pd.merge(left=data, right=commodities, on='COMMODITY_CODE', how='left')
data = pd.merge(left=data, right=districts, on='DISTRICT_CODE', how='left')

# convert numerical parameters to int
num_params = ['VALUE', 'AIR_VALUE', 'AIR_WEIGHT', 'VESSEL_VALUE', 'VESSEL_WEIGHT']
for param in num_params:
    data[param] = pd.to_numeric(data[param], errors='coerce')

# %% [markdown]
# One way to use the data is to export it in `csv` format.

# %%
data.to_csv('C:/Users/Berina/Desktop/Trade Data - API/monthly_trade_data.csv')

# %% [markdown]
# ***

# %% [markdown]
# Depending on the end use, data can be aggregated in many different ways. One way is to get yearly data.

# %%
data.columns
# Out:
# Index(['COUNTRY_CODE', 'VALUE', 'AIR_VALUE', 'AIR_WEIGHT', 'VESSEL_VALUE',
#        'VESSEL_WEIGHT', 'COMMODITY_CODE', 'DISTRICT_CODE', 'EXPORTS', 'YEAR',
#        'MONTH', 'COUNTRY', 'COMMODITY', 'DISTRICT'],
#       dtype='object')

# %%
yearly = data.groupby(['COUNTRY', 'COMMODITY', 'DISTRICT', 'EXPORTS', 'YEAR'], as_index=False) \
                      [['VALUE', 'AIR_VALUE', 'AIR_WEIGHT', 'VESSEL_VALUE', 'VESSEL_WEIGHT']].sum()

# %%
yearly.head()
# Out:
#        COUNTRY                      COMMODITY               DISTRICT  EXPORTS  \
# 0  Afghanistan                   Live Animals         WASHINGTON, DC  Exports
# 1  Afghanistan                   Live Animals         WASHINGTON, DC  Exports
# 2  Afghanistan  Meat and Edible Meat Products  HOUSTON-GALVESTON, TX  Exports
# 3  Afghanistan  Meat and Edible Meat Products  HOUSTON-GALVESTON, TX  Exports
# 4      Albania  Meat and Edible Meat Products  HOUSTON-GALVESTON, TX  Exports
#
#    YEAR   VALUE  AIR_VALUE  AIR_WEIGHT  VESSEL_VALUE  VESSEL_WEIGHT
# 0  2018   54000      54000         840             0              0
# 1  2019   12000      12000         245             0              0
# 2  2018  836482          0           0        836482        1179302
# 3  2019  216059          0           0        216059         249392
# 4  2018  827177          0           0        827177         948330

# %% [markdown]
# Let's also add another

# %%
yearly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2587 entries, 0 to 2586
# Data columns (total 10 columns):
# COUNTRY          2587 non-null object
# COMMODITY        2587 non-null object
# DISTRICT         2587 non-null object
# EXPORTS          2587 non-null object
# YEAR             2587 non-null object
# VALUE            2587 non-null int64
# AIR_VALUE        2587 non-null int64
# AIR_WEIGHT       2587 non-null int64
# VESSEL_VALUE     2587 non-null int64
# VESSEL_WEIGHT    2587 non-null int64
# dtypes: int64(5), object(5)
# memory usage: 222.3+ KB

# %%
countries
# Out:
#     COUNTRY_CODE                               COUNTRY
# 0           5310                           Afghanistan
# 1           4810                               Albania
# 2           7210                               Algeria
# 3           9510                        American Samoa
# 4           4271                               Andorra
# 5           7620                                Angola
# 6           2481                              Anguilla
# 7           2484                   Antigua and Barbuda
# 8           3570                             Argentina
# 9           4631                               Armenia
# 10          2779                                 Aruba
# 11          6021                             Australia
# 12          4330                               Austria
# 13          4632                            Azerbaijan
# 14          2360                               Bahamas
# 15          5250                               Bahrain
# 16          5380                            Bangladesh
# 17          2720                              Barbados
# 18          4622                               Belarus
# 19          4231                               Belgium
# 20          2080                                Belize
# 21          7610                                 Benin
# 22          2320                               Bermuda
# 23          5682                                Bhutan
# 24          3350                               Bolivia
# 25          4793                Bosnia and Herzegovina
# 26          7930                              Botswana
# 27          3510                                Brazil
# 28          7810        British Indian Ocean Territory
# 29          2482                British Virgin Islands
# 30          5610                                Brunei
# 31          4870                              Bulgaria
# 32          7600                          Burkina Faso
# 33          5460                               Myanmar
# 34          7670                               Burundi
# 35          7643                            Cabo Verde
# 36          5550                              Cambodia
# 37          7420                              Cameroon
# 38          1220                                Canada
# 39          2440                        Cayman Islands
# 40          7540              Central African Republic
# 41          7560                                  Chad
# 42          3370                                 Chile
# 43          5700                                 China
# 44          6024                      Christmas Island
# 45          6023               Cocos (Keeling) Islands
# 46          3010                              Colombia
# 47          7890                               Comoros
# 48          7660                        Congo-Kinshasa
# 49          7630                     Congo-Brazzaville
# 50          6142                          Cook Islands
# 51          2230                            Costa Rica
# 52          7480                         Cote d'Ivoire
# 53          4791                               Croatia
# 54          2390                                  Cuba
# 55          2777                               Curacao
# 56          4910                                Cyprus
# 57          4351                        Czech Republic
# 58          4099                               Denmark
# 59          7770                              Djibouti
# 60          2486                              Dominica
# 61          2470                    Dominican Republic
# 62          3310                               Ecuador
# 63          7290                                 Egypt
# 64          2110                           El Salvador
# 65          7380                     Equatorial Guinea
# 66          7741                               Eritrea
# 67          4470                               Estonia
# 68          7950                              Eswatini
# 69          7749                              Ethiopia
# 70          3720                      Falkland Islands
# 71          4091                         Faroe Islands
# 72          6863                                  Fiji
# 73          4050                               Finland
# 74          4279                                France
# 75          3170                         French Guiana
# 76          6414                      French Polynesia
# 77          7905   French Southern and Antarctic Lands
# 78          7550                                 Gabon
# 79          7500                                Gambia
# 80          5082                            Gaza Strip
# 81          4633                               Georgia
# 82          4280                               Germany
# 83          7490                                 Ghana
# 84          4720                             Gibraltar
# 85          4840                                Greece
# 86          1010                             Greenland
# 87          2489                               Grenada
# 88          2831                            Guadeloupe
# 89          9350                                  Guam
# 90          2050                             Guatemala
# 91          7460                                Guinea
# 92          7642                         Guinea-Bissau
# 93          3120                                Guyana
# 94          2450                                 Haiti
# 95          6029     Heard Island and McDonald Islands
# 96          4752                          Vatican City
# 97          2150                              Honduras
# 98          5820                             Hong Kong
# 99          4370                               Hungary
# 100         4000                               Iceland
# 101         5330                                 India
# 102         5600                             Indonesia
# 103         5070                                  Iran
# 104         5050                                  Iraq
# 105         4190                               Ireland
# 106         5081                                Israel
# 107         4759                                 Italy
# 108         2410                               Jamaica
# 109         5880                                 Japan
# 110         5110                                Jordan
# 111         4634                            Kazakhstan
# 112         7790                                 Kenya
# 113         6226                              Kiribati
# 114         4803                                Kosovo
# 115         5130                                Kuwait
# 116         4635                            Kyrgyzstan
# 117         5530                                  Laos
# 118         4490                                Latvia
# 119         5040                               Lebanon
# 120         7990                               Lesotho
# 121         7650                               Liberia
# 122         7250                                 Libya
# 123         4411                         Liechtenstein
# 124         4510                             Lithuania
# 125         4239                            Luxembourg
# 126         5660                                 Macao
# 127         4794                       North Macedonia
# 128         7880                            Madagascar
# 129         7970                                Malawi
# 130         5570                              Malaysia
# 131         5683                              Maldives
# 132         7450                                  Mali
# 133         4730                                 Malta
# 134         6810                      Marshall Islands
# 135         2839                            Martinique
# 136         7410                            Mauritania
# 137         7850                             Mauritius
# 138         7881                               Mayotte
# 139         2010                                Mexico
# 140         6820                            Micronesia
# 141         4641                               Moldova
# 142         4272                                Monaco
# 143         5740                              Mongolia
# 144         4804                            Montenegro
# 145         2485                            Montserrat
# 146         7140                               Morocco
# 147         7870                            Mozambique
# 148         7920                               Namibia
# 149         6862                                 Nauru
# 150         5360                                 Nepal
# 151         4210                           Netherlands
# 152         6412                         New Caledonia
# 153         6141                           New Zealand
# 154         2190                             Nicaragua
# 155         7510                                 Niger
# 156         7530                               Nigeria
# 157         6144                                  Niue
# 158         6022                        Norfolk Island
# 159         5790                           North Korea
# 160         9610              Northern Mariana Islands
# 161         4039                                Norway
# 162         5230                                  Oman
# 163         5350                              Pakistan
# 164         6830                                 Palau
# 165         2250                                Panama
# 166         6040                      Papua New Guinea
# 167         3530                              Paraguay
# 168         3330                                  Peru
# 169         5650                           Philippines
# 170         6225                      Pitcairn Islands
# 171         4550                                Poland
# 172         4710                              Portugal
# 173         9030                           Puerto Rico
# 174         5180                                 Qatar
# 175         7904                               Reunion
# 176         4850                               Romania
# 177         4621                                Russia
# 178         7690                                Rwanda
# 179         7580                          Saint Helena
# 180         2483                 Saint Kitts and Nevis
# 181         2487                           Saint Lucia
# 182         1610             Saint Pierre and Miquelon
# 183         2488      Saint Vincent and the Grenadines
# 184         6150                                 Samoa
# 185         4751                            San Marino
# 186         7644                 Sao Tome and Principe
# 187         5170                          Saudi Arabia
# 188         7440                               Senegal
# 189         4801                                Serbia
# 190         7800                            Seychelles
# 191         7470                          Sierra Leone
# 192         5590                             Singapore
# 193         2774                          Sint Maarten
# 194         4359                              Slovakia
# 195         4792                              Slovenia
# 196         6223                       Solomon Islands
# 197         7700                               Somalia
# 198         7910                          South Africa
# 199         5800                           South Korea
# 200         7323                           South Sudan
# 201         4700                                 Spain
# 202         5420                             Sri Lanka
# 203         7321                                 Sudan
# 204         3150                              Suriname
# 205         4031                Svalbard and Jan Mayen
# 206         4010                                Sweden
# 207         4419                           Switzerland
# 208         5020                                 Syria
# 209         5830                                Taiwan
# 210         4642                            Tajikistan
# 211         7830                              Tanzania
# 212         5490                              Thailand
# 213         5601                           Timor-Leste
# 214         7520                                  Togo
# 215         6143                               Tokelau
# 216         6864                                 Tonga
# 217         2740                   Trinidad and Tobago
# 218         7230                               Tunisia
# 219         4890                                Turkey
# 220         4643                          Turkmenistan
# 221         2430              Turks and Caicos Islands
# 222         6227                                Tuvalu
# 223         7780                                Uganda
# 224         4623                               Ukraine
# 225         5200                  United Arab Emirates
# 226         4120                        United Kingdom
# 227         9800  United States Minor Outlying Islands
# 228         1000              United States of America
# 229         3550                               Uruguay
# 230         4644                            Uzbekistan
# 231         6224                               Vanuatu
# 232         3070                             Venezuela
# 233         5520                               Vietnam
# 234         9110   Virgin Islands of the United States
# 235         6413                     Wallis and Futuna
# 236         5083                             West Bank
# 237         7370                        Western Sahara
# 238         5210                                 Yemen
# 239         7940                                Zambia
# 240         7960                              Zimbabwe

# %%
yearly[yearly['COUNTRY'] == 'Chad']
# Out:
# Empty DataFrame
# Columns: [COUNTRY, COMMODITY, DISTRICT, EXPORTS, YEAR, VALUE, AIR_VALUE, AIR_WEIGHT, VESSEL_VALUE, VESSEL_WEIGHT]
# Index: []
